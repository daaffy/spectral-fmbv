# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.insert(1,'./../../../src')


import methods
import matplotlib.pyplot as plt
import networkx as nx
import scipy
import numpy as np
import betterspy

import qtree_methods as qtm

from sklearn.cluster import KMeans
# Out:
# ERROR:root:Error during import of compiled filters!
# ERROR:root:No module named 'png.pngfilters'
# ERROR:root:Fallback to pure python mode!

# %%
SLICE = 25
bias = 10


img_array, _ = methods.pd_3d(zoom = 0.3, base='wl1_5')
# img_array, _ = methods.pd_3d(zoom=0.3)
mask_array = img_array > 0


plt.imshow(img_array[:,SLICE,:])
# plt.imshow(img_array[:,SLICE,:])

# %%
wf = methods.WeightKernel(
    dist_sig = 1,
    intensity_sig = 40
)

# problem with mask?
G = methods.ImageGraph(
    img_array, 
    mask_array=mask_array, 
    wf=wf, 
    neighbour_depth = 2, 
    cmap='viridis'
    )
# Out:
# start
# end
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       1 wf = methods.WeightKernel(
#       2     dist_sig = 1,
#       3     intensity_sig = 40
#       4 )
#       6 # problem with mask?
# ----> 7 G = methods.ImageGraph(
#       8     img_array,
#       9     mask_array=mask_array,
#      10     wf=wf,
#      11     neighbour_depth = 2,
#      12     cmap='viridis'
#      13     )
#
# File ~/Documents/FMBV_2023/Spectral FMBV/paper/case_studies/circle_of_willis/./../../../src/methods.py:231, in ImageGraph.__init__(self, img_array, mask_array, wf, neighbour_depth, cmap, zero_node_threshold)
#     229 self.dist, self.v_coords = _distance_information_from_img_array(img_array, neighbour_depth=neighbour_depth)
#     230 print("end")
# --> 231 self._img_array_to_graph()
#     232 # self.G = _img_array_to_graph(img_array, mask_array = self.mask_array, neighbour_depth=self.neighbour_depth, pixel_sig=5, img_sig=30)
#     233
#     234 # NOTE:
#    (...)
#     237 # this node does not represent any pixel in the image. it is important to distinguise when we do things like
#     238 # _node_vec_to_img_array, __set_node_color etc.
#     239 self.img_nodes = list(self.nodes)
#
# File ~/Documents/FMBV_2023/Spectral FMBV/paper/case_studies/circle_of_willis/./../../../src/methods.py:291, in ImageGraph._img_array_to_graph(self)
#     288     continue
#     290 # then calculate the intensity difference
# --> 291 intensity_dist = np.abs(self.img_array[*self.v_coords[j1,:]]-self.img_array[*self.v_coords[j2,:]])
#     293 # weight (affinity) between nodes depends on distance in both pixel distance and pixel intensity space.
#     294 # w = _w1(self.dist.data[i], intensity_dist,  dist_sig=dist_sig, intensity_sig=intensity_sig)
#     295 w = self.wf.eval(self.dist.data[i], intensity_dist)
#
# KeyboardInterrupt:

# %%
G._create_zero_node(zero_node_threshold=30)

# %%
# nx.write_gexf(G, 'zero-node.gexf')

# %%
# nx.write_gexf(G, 'cow.gexf')

# %%
P = nx.normalized_laplacian_matrix(G)
N = P.shape[0]

# %%
print(N)
print(P.nnz/N**2)
# Out:
# 47641
# 0.0006902785574713221

# %%
solve_matrix = -(P-scipy.sparse.identity(N))
# %timeit vals, vecs = scipy.sparse.linalg.eigs(solve_matrix, which='LM')
vals, vecs = scipy.sparse.linalg.eigs(solve_matrix, which='LR')

# %%
# %timeit vals, vecs = scipy.sparse.linalg.eigs(P, which='SR')

# %%
i = 4
eig_img = G._node_vec_to_img_array(np.real(vecs[:,i]))

# %%
plt.imshow(eig_img[SLICE,:,:])

# %%
plt.plot(vals)
# Out:
# /Users/jackh/opt/anaconda3/envs/gordon_original/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
cluster_num = 5

kmeans = KMeans(n_clusters=cluster_num, random_state=0, n_init="auto").fit(np.real(vecs[:,:3]))
labels = kmeans.labels_+1

# %%
k_img = G._node_vec_to_img_array(labels)
# Out:
# skip

# %%
plt.imshow(k_img[:,:])

# %%
fig, axs = plt.subplots(1, cluster_num) 
fig.set_figheight(4)
fig.set_figwidth(20)

for i in range(1,cluster_num+1):
    curr = k_img == i
    axs[i-1].imshow(curr[:,:], cmap='prism')

# %%
S, R  = methods.SEBA(np.real(vecs)[:,:3])

# %%
seba_sum =  np.sum(S, axis=1)
seba_img = G._node_vec_to_img_array(seba_sum)
# Out:
# skip

# %%
plt.imshow(seba_img[:,:])

# %%
seba_component_img = G._node_vec_to_img_array(S[:,2])
plt.imshow(seba_component_img[:,:])
# Out:
# skip

# %%
# TRACE DRAFT

def show_trace(img, mask = None, axis=0):
    if mask is None:
        mask = np.full(img.shape, True)
    
    # assert
    mask_color = mask

    mask_flat = (mask > 0).flatten()
    img_flat = img.flatten()
    mask_color_flat = mask_color.flatten()

    xys = np.meshgrid(range(img.shape[1]),range(img.shape[0]))
    
    d_flat = xys[axis].flatten()

    plt.figure()
    plt.scatter(d_flat[mask_flat], img_flat[mask_flat], c = img_flat[mask_flat])

    plt.figure()
    plt.scatter(d_flat[mask_flat], img_flat[mask_flat], c = mask_color_flat[mask_flat])


show_trace(img_array, mask = seba_img, axis=0)
